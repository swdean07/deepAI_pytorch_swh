# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np

##############################################################
import json
import re

# ✅ JSON 파일 읽기
file_path = "/content/drive/MyDrive/busanit501-1234/트럼프_naver_news.json"

with open(file_path, "r", encoding="utf-8") as file:
    news_data = json.load(file)  # JSON 데이터 로드
##############################################################

# ✅ 샘플 데이터셋 (문장 예제)
corpus = [
   "나는 너를 사랑해",
    "나는 코딩을 좋아해",
    "너는 나를 좋아해",
    "너는 파이썬을 공부해",
    "우리는 인공지능을 연구해",
    "딥러닝은 재미있어",
    "파이썬은 강력해",
    "나는 자연어처리를 공부해",
]
##############################################################
# ✅ JSON 데이터에서 'title' 값만 추출하고 한글만 남기기
def extract_korean(text):
    """문장에서 한글만 남기는 함수"""
    return re.sub(r"[^ㄱ-ㅎ가-힣 ]+", " ", text)

news_titles = [extract_korean(item["title"]) for item in news_data if "title" in item]

# ✅ corpus에 한글만 남긴 뉴스 제목 추가
corpus.extend(news_titles)

# ✅ 결과 출력
print("📌 최종 corpus 리스트:")
print(corpus)
##############################################################

# ✅ 단어 사전 만들기 (Tokenization)
word_list = list(set(" ".join(corpus).split()))
word_dict = {w: i for i, w in enumerate(word_list)}
idx_dict = {i: w for w, i in word_dict.items()}
# Out:
# 📌 최종 corpus 리스트:
# ['나는 너를 사랑해', '나는 코딩을 좋아해', '너는 나를 좋아해', '너는 파이썬을 공부해', '우리는 인공지능을 연구해', '딥러닝은 재미있어', '파이썬은 강력해', '나는 자연어처리를 공부해', ' 싸운 건  쇼 로이터   미 우크라 간 광물협정 체결할 수도 ', ' 속보 트럼프   무역전쟁 에도   올해 경제성장률   안팎  목표', '뉴욕증시  관세전쟁 격화에  일 연속 하락 마감', ' 우크라 광물협정 임박 보도에 재무  지금은 아냐 ', ' 트럼프  개입했지만  투어 커미셔너  와 통합 쉽지 않다 ', '  엔비디아 급반등 이어 삼성전자    하이닉스  상승 출발 ', '미국 부통령  우크라 파병 추진 유럽국에  어중이떠중이  지칭 논란', '루비오 방문 한 달만에 홍콩 기업 결국 파나마운하 항만지분 미국 기업 ', ' 트럼프  관세   협상용 엄포  아닌  진심 그럼에도   증시 기 ', '전진건설로봇 주가 방긋 우크라이나 전쟁 종전 임박', ' 물동량  만 시대 마중물  인천신항 완전자동화부두 조성 순항', ' 해외브리핑  미    억  규모 태양광 프로그램 보조금 동결 해제', '코스피    증시 변동성 속 상승 출발 선 등락', ' 미국 술 치워라 캐나다 주 정부들  트럼프  관세에 맞불', '  김여정  칼빈슨함  발끈하자  한국 방어 공약 분명 ', '대성하이텍  방산 수주 비중 급증 유럽 및 이스라엘과 장기 계약 기대 ', '코스닥  외인 기관 사자에  대 상승 선', '미 상무  중간서 만날 수도 캐 멕 관세 경감 가능 시사', ' 트럼프  캐나다  총리 를  주지사 로 호칭 상호관세 부과 으름장', ' 상무  트럼프   멕 관세 경감 고려 내일 발표할 듯 상보 ', '  원조중단에 속탄 젤렌스키  백악관 일 유감 바로잡을 때 ', '  국방차관 후보  한국 정치상황에 공개 우려 입장', '예수회난민봉사기구  지원 중단에 활동 위축 우려', ' 보스레이디 로 변신한 멜라니아 슈트 빼입고 성큼 돌진', '미 상무  중간서 만날 수도 일 캐 멕 관세 경감 가능성 시사', '여 지도부  철강산업 현장간담회 경주   현장 점검', ' 트럼프  암호화폐 비축 계획  업계 대립 초래', ' 로부터 안보 독립 꾀하는 유럽 재무장에  조 쓴다', ' 글로벌칼럼  프란치스코 교황의 입원이 불러온 예상치 못한 영향', '  다음 타자는 헤데라 나스닥   에 핵심 서류 제출', ' 뉴욕증시  관세전쟁 격화 양상에 일제히 하락 테슬라  ', '  멕    관세 경감 가능성 이르면  일 발표', ' 트럼프  관세    토요타보다 현대 기아 사정 낫지만  우리도 풍전등 ', '  암호화폐 준비금보다 관세 공포 컸다 비트코인 부진 계속', '박용진  비명횡사 악연  민주당 승리라는 대의명분 우선   나는정치인이 ', '아랍연맹  자체 가자 재건 계획  채택   트럼프  구상에 반발', '로이터  트럼프  오늘 연설서 우크라와 광물협정 발표 베센트  재무 ', ' 트럼프 발 관세 전쟁이   전기차 시장에 미치는 영향', ' 투자   무역전쟁 우려는 과도 딥시크 덕   확산 ', '비트코인  폭락 끝났나    상승이 가리키는 강세장 신호 ', ' 트럼프  이민자 추방 계획  미국 육가공 산업에 타격 줄까', ' 뉴욕마켓워치   트럼프  관세 충격에 주가 달러 하락 지속 국채 혼조', '로이터  우크라 광물협상 타결 일  트럼프  의회 연설 때 발표 ', '미 상무부 장관  중간서 만날 수도 일 캐나다 멕시코 관세 경감 가능 ', ' 아주증시포커스  하루  시간 주식 거래 넥스트레이드 출범 첫날  ', '트뤼도  총리  조 규모 미국산 수입품에 보복관세 즉각 발효 ', '안도걸  쿼드러플 경기 추락 추경 편성 필요 ', '정부 지출 증가에 유로화 올들어 최고치 증시는 급락', ' 중국이 한국 정치 개입  믿을수록 반민주적  시사 한국리서치 공 ', ' 상무  중간서 만날 수도 일  멕 관세 경감 가능성 시사', ' 초점  기로에 선   달러  약세 전망  솔솔 엔화 주목해야', ' 부통령  우크라 파병 추진 유럽국에  어중이떠중이  지칭 논란', '벨라루스 대통령  암호화폐 채굴 개발 지시 전력 남아돈다 ', ' 트럼프  관세 직격탄 암호화폐 파생상품 하루 만  억달러 청산', ' 우크라 광물협정 임박 보도 나왔지만  재무  지금은 아냐 종합 ', '윤석열 최후의 변명 팩트체크  쿠데타의 재구성 ', '울산시   트럼프   기 통상정책 대응  유관기관 대책회의  개최', ' 테슬라 전기차 안 사 주가 또   급락   트럼프  상승분 대부분 반납', '리플 등 가상화폐  오는  일  트럼프  가상화폐 회의에 운명 달려', ' 젤렌스키는 영웅   트럼프 는 빵점 ', '이번엔  보스 레이디 멜라니아   트럼프   기와 다른 패션', ' 출근길 뉴스프레소  상무  관세 철회 할수도   트럼프  일보 후퇴    직격 ', '  주식 이어   사들인 투자자들  상품 경쟁 가속', '뉴욕 연은 총재  관세 물가 영향 연내 나타날 것 ', '공포탐욕지수  극단적 공포  수준  하나증권  텔레콤     한국전력 ', '아랍국가들  자체 팔레스타인 재건 계획 채택 팔레스타인인 자신들 ', ' 국방차관 후보   전작권 이전에  의욕적인 동맹국  역할 강화 지지 ', '사운드웨이브 부사장 최원준     내가 사는 세상을 사실에 가깝게 보는 ', ' 트럼프   파나마 운하  항구 운영권 찾아왔다', ' 오늘의 투자전략  국내 증시  미국과 멕시코 캐나다 관세 협상 가능성 ', '  상무장관   트럼프  멕시코 캐나다와 무역협상 타결 내일 발표할수 ', ' 글로벌 마켓 리포트  월  일 ', ' 안성진의 본투비 지구과학 이야기  그린란드와 지구과학', '  파운드리 장악력 높이는   수세 몰리는 삼성전자', '대통령도 나섰는데   투어 커미셔너  와 통합 쉽지 않다 ', ' 트럼프  무역 전쟁  미국보다 캐나다 멕시코 큰 타격 ', '관세부과 첫날부터 보복선언 추가위협 트럼프  무역전쟁 본격화', ' 트뤼도 주지사  보복 관세  그럼 우린 또 올려  재보복 위협한 트 ', ' 오늘의 뉴욕증시 무버  관세전쟁에 인플레 우려한 유통주 폭락 베스트 ', '뉴욕증시   트럼프  관세 격화에 약세 다우   하락', '두산밥캣 북미 생산으로 업황 반등 수혜 기대  한화투자  목표주가 상향 ', ' 뉴욕 브리핑   트럼프  관세전쟁 격화 뉴욕증시 동반 하락', '미국이 군사 지원 중단하자 젤렌스키가 제안한 것은', ' 국방차관 후보  동북아 동맹국에 국방비 증액 요구', '테슬라 전고점 대비   폭락  어디까지 떨어지나 종합 ', '연준 윌리엄스  트럼프  관세 물가 영향  올 하반기 나타날 듯 ', ' 미장브리핑    관세 부과에   보복 조치 단행 예고', '   원 원 원 하락', ' 뉴욕 금가격   트럼프  관세 어부지리 달러 약세 연일 반등', '울산시  수출유관기관 대책 회의 개최', ' 국방차관 후보   전작권 이전 관련  역할 강화 지지 ', '  상무  중간서 만날 수도 캐나다 멕시코 향해 관세 경감 가능성 ', ' 종합  젤렌스키  백악관 일 후회 우크라 공중 해상 휴전 제안 ', ' 박정식의 국내 주식시황  관세전쟁 시작되며 인플레이션 및 경기침체  ', '로이터  미국 우크라 광물 협정  이르면 몇 시간 내 타결 가능성 ', '에버코어 가 꼽은 무역전쟁 중 보유하기 좋은 주식은', ' 투자   무역전쟁 우려는 과도 딥시크 덕   확산 ', '비트코인  억 만 원대 상승  시장 둔화에도 장기적 강세 흐름 유지 전 ', ' 상무  캐나다 멕시코 관세 경감 시사 트럼프   일 타협안 발표할 ', ' 속보  미국 상무  중간서 만날 수도 일  멕 관세 경감 가능성 시 ', ' 경기 둔화 키우는  트럼프  관세 환율  원대로 하락 외환브리핑 ', '고개 숙인 젤렌스키  트럼프  리더십 아래 평화노력 준비돼    공중 해 ', '   캐 멕 관세  가장 어리석은 세금 트럼프  고삐 풀린 관세맨 ', '      우기홍 대한항공 대표이사 부회장', ' 엔비디아 저평가 년 내 최저 수준 근접 ', '  오늘 포항서  철강산업 위기극복  현장 간담회', ...

# %%
# ✅ 데이터셋 변환
def make_data(corpus):
    inputs, targets = [], []
    for sentence in corpus:
        words = sentence.split()
        for i in range(len(words) - 1):  # "I love" -> "you"
            x = [word_dict[w] for w in words[:i+1]]
            y = word_dict[words[i+1]]
            inputs.append(x)
            targets.append(y)

    return inputs, targets

inputs, targets = make_data(corpus)

# ✅ 패딩 추가 (문장 길이를 맞춤)
max_len = max(len(seq) for seq in inputs)
inputs_padded = [seq + [0] * (max_len - len(seq)) for seq in inputs]
targets = torch.tensor(targets, dtype=torch.long)

# ✅ 데이터셋 및 DataLoader 생성
class TextDataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = torch.tensor(inputs, dtype=torch.long)
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

dataset = TextDataset(inputs_padded, targets)
train_loader = DataLoader(dataset, batch_size=2, shuffle=True)

vocab_size = len(word_dict)  # 단어 개수
embed_size = 10  # 임베딩 차원
hidden_size = 16  # RNN 은닉층 크기
num_classes = len(word_dict)  # 예측할 단어 개수

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ✅ GRU 모델 정의
class GRUTextModel(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, num_classes):
        super(GRUTextModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)  # 단어 임베딩
        self.gru = nn.GRU(embed_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        out, _ = self.gru(x)
        out = self.fc(out[:, -1, :])  # 마지막 시점의 GRU 출력을 사용
        return out

# ✅ 모델 생성
model = GRUTextModel(vocab_size, embed_size, hidden_size, num_classes)

# ✅ GPU 사용 가능하면 이동
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# ✅ 손실 함수 및 최적화 함수 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
num_epochs = 100
print("🚀 GRU 모델 학습 시작...")
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    if (epoch + 1) % 1 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}")

# ✅ 모델 저장
model_path = "/content/drive/MyDrive/busanit501-1234/gru_news_model.pth"
torch.save(model.state_dict(), model_path)
print(f"✅ 학습된 모델이 저장되었습니다: {model_path}")
# Out:
# 🚀 GRU 모델 학습 시작...

# %%
model_path = "/content/drive/MyDrive/busanit501-1234/gru_news_model.pth"
# ✅ 저장된 RNN 모델 불러오기
def load_model(model_path, vocab_size, embed_size, hidden_size, num_classes):
    model = LSTMTextModel(vocab_size, embed_size, hidden_size, num_classes)
    model.load_state_dict(torch.load(model_path, map_location=torch.device("cpu")))
    model.eval()
    return model

# ✅ 모델 불러오기
loaded_model = load_model(model_path, vocab_size, embed_size, hidden_size, num_classes)
print("✅ 모델이 성공적으로 불러와졌습니다!")
# Out:
# ✅ 모델이 성공적으로 불러와졌습니다!

# %%
import torch.nn.functional as F

def predict_next_word(model, sentence):
    """
    저장된 RNN 모델을 사용하여 주어진 문장의 다음 단어를 예측하는 함수.
    """
    # ✅ 입력 문장을 정수 인코딩
    words = sentence.split()
    input_seq = [word_dict[w] for w in words if w in word_dict]

    # ✅ 패딩 추가 (길이를 맞추기 위해)
    input_padded = input_seq + [0] * (max_len - len(input_seq))
    input_tensor = torch.tensor([input_padded], dtype=torch.long)

    # ✅ 모델 예측
    with torch.no_grad():
        output = model(input_tensor)
        probabilities = F.softmax(output[0], dim=0)
        predicted_idx = torch.argmax(probabilities).item()
        confidence = probabilities[predicted_idx].item()

    predicted_word = idx_dict[predicted_idx]

    print(f"🔍 입력 문장: '{sentence}'")
    print(f"📊 예측된 단어: '{predicted_word}'")
    print(f"✅ 예측 확률: {confidence * 100:.2f}%")

# 🏆 샘플 문장 예측 실행
sample_sentence = "호칭  "
predict_next_word(loaded_model, sample_sentence)
# Out:
# 🔍 입력 문장: '호칭  '
# 📊 예측된 단어: '트럼프'
# ✅ 예측 확률: 3.18%
